# %% [markdown]
# ## 578hw3.ipynb
# ## RASHEED HAMEED
# > - CSC 578 Neural Networks and Deep Learning – Section 910
# > -Homework #5
#
# # 578hw5 -- Start-up application code

# %% [markdown]
# ## (0) Tiny experiment with One-training-One-test Iris data
# ### [You can run the start-up code as is to generate this.]

# %%
import NN578_network2 as network2
import numpy as np

# Test with one-data Iris data

inst1 = (np.array([5.7, 3, 4.2, 1.2]), np.array([0., 1., 0.]))
x1 = np.reshape(inst1[0], (4, 1))
y1 = np.reshape(inst1[1], (3, 1))
sample1 = [(x1, y1)]
inst2 = (np.array([4.8, 3.4, 1.6, 0.2]), np.array([1., 0., 0.]))
x2 = np.reshape(inst2[0], (4, 1))
y2 = np.reshape(inst2[1], (3, 1))
sample2 = [(x2, y2)]

net4 = network2.load_network("iris-423.dat")
net4.set_parameters(cost=network2.QuadraticCost)

net4.SGD(sample1, 2, 1, 1.0, evaluation_data=sample2, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.26673128660052947
# Accuracy on training data: 1 / 1
# Cost on evaluation data: 0.3244002758397572
# Accuracy on evaluation data: 0 / 1
#
# Epoch 1 training complete
# Cost on training data: 0.2107866577006649
# Accuracy on training data: 1 / 1
# Cost on evaluation data: 0.37647122809828165
# Accuracy on evaluation data: 0 / 1
#
# Training error:
#  0.26673128660052947
#  0.2107866577006649
#
# Training correct:
#  [1, 1]
#
# Test error:
#  0.3244002758397572
#  0.37647122809828165
#
# Test correct:
#  [0, 0]

# %% [markdown]
# ## Load the iris_train, iris_test datasets

# %%
# Load the iris train-test (separate) data files
def my_load_csv(fname, no_trainfeatures, no_testfeatures):
    ret = np.genfromtxt(fname, delimiter=',')
    data = np.array([(entry[:no_trainfeatures],entry[no_trainfeatures:]) for entry in ret])
    temp_inputs = [np.reshape(x, (no_trainfeatures, 1)) for x in data[:,0]]
    temp_results = [np.reshape(y, (no_testfeatures, 1)) for y in data[:,1]]
    dataset = list(zip(temp_inputs, temp_results))
    return dataset

iris_train = my_load_csv('iris-train-1.csv', 4, 3)
iris_test = my_load_csv('iris-test-1.csv', 4, 3)

# %% [markdown]
# ## (1) Sigmoid + Sigmoid + QuadraticCost  (RESULT1)
# ### [You can run the start-up code as is to generate this.]

# %%
net2 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net2.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid)

net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.3392795030659105
# Accuracy on training data: 21 / 95
# Cost on evaluation data: 0.34444833747414394
# Accuracy on evaluation data: 15 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.3332680387432046
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3357508215659017
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.33169864345910943
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33331819877313307
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.3280047701277544
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.32931297694327877
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3105024143021552
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.311452504680719
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.2822226213778409
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.2826664474869378
# Accuracy on evaluation data: 39 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.26185308519985034
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.26222211632361037
# Accuracy on evaluation data: 40 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.24637620748622574
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.24693122708939252
# Accuracy on evaluation data: 40 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.23397287354343002
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.23484243915532602
# Accuracy on evaluation data: 41 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.2240389321795399
# Accuracy on training data: 67 / 95
# Cost on evaluation data: 0.22523745295521988
# Accuracy on evaluation data: 41 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.21604989548513004
# Accuracy on training data: 70 / 95
# Cost on evaluation data: 0.21755153109277017
# Accuracy on evaluation data: 44 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.2095762015532569
# Accuracy on training data: 73 / 95
# Cost on evaluation data: 0.21134700807259035
# Accuracy on evaluation data: 47 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.20428080318467826
# Accuracy on training data: 81 / 95
# Cost on evaluation data: 0.20628846293823358
# Accuracy on evaluation data: 52 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.19990418595499365
# Accuracy on training data: 94 / 95
# Cost on evaluation data: 0.20212044282632813
# Accuracy on evaluation data: 54 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.19624754621498341
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.19864854335473608
# Accuracy on evaluation data: 35 / 55
#
# Training error:
#  0.3392795030659105
#  0.3332680387432046
#  0.33169864345910943
#  0.3280047701277544
#  0.3105024143021552
#  0.2822226213778409
#  0.26185308519985034
#  0.24637620748622574
#  0.23397287354343002
#  0.2240389321795399
#  0.21604989548513004
#  0.2095762015532569
#  0.20428080318467826
#  0.19990418595499365
#  0.19624754621498341
#
# Training correct:
#  [21, 33, 33, 33, 65, 64, 65, 64, 65, 67, 70, 73, 81, 94, 65]
#
# Test error:
#  0.34444833747414394
#  0.3357508215659017
#  0.33331819877313307
#  0.32931297694327877
#  0.311452504680719
#  0.2826664474869378
#  0.26222211632361037
#  0.24693122708939252
#  0.23484243915532602
#  0.22523745295521988
#  0.21755153109277017
#  0.21134700807259035
#  0.20628846293823358
#  0.20212044282632813
#  0.19864854335473608
#
# Test correct:
#  [15, 17, 17, 17, 35, 39, 40, 40, 41, 41, 44, 47, 52, 54, 35]

# %% [markdown]
# ## (2) Sigmoid + Sigmoid + CrossEntropyCost (Result2)

# %%
net2 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net2.set_parameters(cost=network2.CrossEntropyCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid)

net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.8603802674198153
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.86801026041802
# Accuracy on evaluation data: 18 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.460606534019205
# Accuracy on training data: 69 / 95
# Cost on evaluation data: 1.4660555356377223
# Accuracy on evaluation data: 44 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.2667163241805766
# Accuracy on training data: 92 / 95
# Cost on evaluation data: 1.2774861545892018
# Accuracy on evaluation data: 54 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.157146339882345
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.1718471307186422
# Accuracy on evaluation data: 35 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.0668798505712163
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.086639159620854
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.0269316288572257
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0468525231446604
# Accuracy on evaluation data: 35 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.0030159043215203
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0230817418856184
# Accuracy on evaluation data: 35 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.9876051818657172
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0083454504660283
# Accuracy on evaluation data: 35 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.9772276017636307
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.9990397749812812
# Accuracy on evaluation data: 35 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.9690604086884842
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.991678203636846
# Accuracy on evaluation data: 35 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.9623999454604477
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.9856464279019423
# Accuracy on evaluation data: 35 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.9564443218222219
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.9800468983199271
# Accuracy on evaluation data: 35 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.9519759891060906
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.9761371328834562
# Accuracy on evaluation data: 34 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.9459190082319843
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.9696831841725918
# Accuracy on evaluation data: 35 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.9566747295346775
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.984622053444025
# Accuracy on evaluation data: 34 / 55
#
# Training error:
#  1.8603802674198153
#  1.460606534019205
#  1.2667163241805766
#  1.157146339882345
#  1.0668798505712163
#  1.0269316288572257
#  1.0030159043215203
#  0.9876051818657172
#  0.9772276017636307
#  0.9690604086884842
#  0.9623999454604477
#  0.9564443218222219
#  0.9519759891060906
#  0.9459190082319843
#  0.9566747295346775
#
# Training correct:
#  [33, 69, 92, 65, 65, 65, 65, 65, 65, 65, 64, 64, 64, 64, 64]
#
# Test error:
#  1.86801026041802
#  1.4660555356377223
#  1.2774861545892018
#  1.1718471307186422
#  1.086639159620854
#  1.0468525231446604
#  1.0230817418856184
#  1.0083454504660283
#  0.9990397749812812
#  0.991678203636846
#  0.9856464279019423
#  0.9800468983199271
#  0.9761371328834562
#  0.9696831841725918
#  0.984622053444025
#
# Test correct:
#  [18, 44, 54, 35, 35, 35, 35, 35, 35, 35, 35, 35, 34, 35, 34]

# %% [markdown]
# ## (3) Sigmoid + Softmax + CrossEntropy (Result 3)

# %%
net4 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net4.set_parameters(cost=network2.CrossEntropyCost, act_hidden=network2.Sigmoid, act_output=network2.Softmax)

net4.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.8524910333322135
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 1.8412155370924923
# Accuracy on evaluation data: 20 / 55
#
# Epoch 1 training complete
# Cost on training data: 2.0598310577877728
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.0738956457705893
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 2.0579394075124076
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.065183511202047
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 2.0546746303186554
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.0627102215395867
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 2.023936880475182
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.039948322445991
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 2.170800056625196
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.1776955186708062
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.266676963043007
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.2808259420232928
# Accuracy on evaluation data: 35 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.114977094967534
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 1.126018508021796
# Accuracy on evaluation data: 38 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.0546347142270684
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 1.066698805050286
# Accuracy on evaluation data: 38 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.0226542072356248
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0357969246744323
# Accuracy on evaluation data: 35 / 55
#
# Epoch 10 training complete
# Cost on training data: 1.0027999156295482
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0167497814357358
# Accuracy on evaluation data: 35 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.9892904411343216
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0037523328056734
# Accuracy on evaluation data: 35 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.979511636363013
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.994181027155807
# Accuracy on evaluation data: 35 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.9719553639611374
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.9865879002863005
# Accuracy on evaluation data: 35 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.9652283721054262
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.9799852551205157
# Accuracy on evaluation data: 35 / 55
#
# Training error:
#  1.8524910333322135
#  2.0598310577877728
#  2.0579394075124076
#  2.0546746303186554
#  2.023936880475182
#  2.170800056625196
#  1.266676963043007
#  1.114977094967534
#  1.0546347142270684
#  1.0226542072356248
#  1.0027999156295482
#  0.9892904411343216
#  0.979511636363013
#  0.9719553639611374
#  0.9652283721054262
#
# Training correct:
#  [30, 33, 33, 33, 33, 33, 65, 62, 62, 65, 65, 65, 65, 65, 65]
#
# Test error:
#  1.8412155370924923
#  2.0738956457705893
#  2.065183511202047
#  2.0627102215395867
#  2.039948322445991
#  2.1776955186708062
#  1.2808259420232928
#  1.126018508021796
#  1.066698805050286
#  1.0357969246744323
#  1.0167497814357358
#  1.0037523328056734
#  0.994181027155807
#  0.9865879002863005
#  0.9799852551205157
#
# Test correct:
#  [20, 17, 17, 17, 17, 17, 35, 38, 38, 35, 35, 35, 35, 35, 35]

# %% [markdown]
# ## (4) Sigmoid + Softmax + LogLikelihood (Result 4)

# %%
net4 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net4.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.Sigmoid, act_output=network2.Softmax)

net4.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.0725541578143791
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.0757367096860873
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.7394112289313796
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.7407176979301714
# Accuracy on evaluation data: 40 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.6205618473893995
# Accuracy on training data: 85 / 95
# Cost on evaluation data: 0.6257845728763476
# Accuracy on evaluation data: 52 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.5670736844143868
# Accuracy on training data: 93 / 95
# Cost on evaluation data: 0.5731784036177967
# Accuracy on evaluation data: 54 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.5333770349417168
# Accuracy on training data: 88 / 95
# Cost on evaluation data: 0.5400095734834603
# Accuracy on evaluation data: 54 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.5023152528399535
# Accuracy on training data: 81 / 95
# Cost on evaluation data: 0.5103342513102356
# Accuracy on evaluation data: 51 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.49562244982507936
# Accuracy on training data: 83 / 95
# Cost on evaluation data: 0.5032223921305509
# Accuracy on evaluation data: 51 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.2091077532521386
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 1.1812599586020018
# Accuracy on evaluation data: 20 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.4959209670421318
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.5043047769715204
# Accuracy on evaluation data: 35 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.48173436665896074
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.4891587734008434
# Accuracy on evaluation data: 35 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.47309096708484466
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.4792400201763873
# Accuracy on evaluation data: 35 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.4770244676851446
# Accuracy on training data: 71 / 95
# Cost on evaluation data: 0.4838323639883707
# Accuracy on evaluation data: 46 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.4717382886945282
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.47838614104699667
# Accuracy on evaluation data: 35 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.6019085509668145
# Accuracy on training data: 51 / 95
# Cost on evaluation data: 0.5645536612368064
# Accuracy on evaluation data: 29 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.7069201483472336
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.7042809321852513
# Accuracy on evaluation data: 40 / 55
#
# Training error:
#  1.0725541578143791
#  0.7394112289313796
#  0.6205618473893995
#  0.5670736844143868
#  0.5333770349417168
#  0.5023152528399535
#  0.49562244982507936
#  1.2091077532521386
#  0.4959209670421318
#  0.48173436665896074
#  0.47309096708484466
#  0.4770244676851446
#  0.4717382886945282
#  0.6019085509668145
#  0.7069201483472336
#
# Training correct:
#  [33, 65, 85, 93, 88, 81, 83, 30, 65, 65, 65, 71, 65, 51, 64]
#
# Test error:
#  1.0757367096860873
#  0.7407176979301714
#  0.6257845728763476
#  0.5731784036177967
#  0.5400095734834603
#  0.5103342513102356
#  0.5032223921305509
#  1.1812599586020018
#  0.5043047769715204
#  0.4891587734008434
#  0.4792400201763873
#  0.4838323639883707
#  0.47838614104699667
#  0.5645536612368064
#  0.7042809321852513
#
# Test correct:
#  [17, 40, 52, 54, 54, 51, 51, 20, 35, 35, 35, 46, 35, 29, 40]

# %% [markdown]
# ## (5) ReLU + Softmax + CrossEntropy (Result 5)

# %%
net5 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net5.set_parameters(cost=network2.CrossEntropyCost, act_hidden=network2.ReLU, act_output=network2.Softmax)

net5.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.9109220175706492
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192231681687888
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.9109281127659505
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497719649038
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.9109281129918982
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836280689
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.9109281129902884
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353035
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.9109281129902855
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Training error:
#  1.9109220175706492
#  1.9109281127659505
#  1.9109281129918982
#  1.9109281129902884
#  1.9109281129902855
#  1.9109281129902858
#  1.9109281129902866
#  1.9109281129902858
#  1.9109281129902866
#  1.9109281129902858
#  1.9109281129902866
#  1.9109281129902858
#  1.9109281129902866
#  1.9109281129902858
#  1.9109281129902866
#
# Training correct:
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33]
#
# Test error:
#  1.9192231681687888
#  1.9192497719649038
#  1.9192497836280689
#  1.9192497836353035
#  1.9192497836353115
#  1.9192497836353113
#  1.9192497836353115
#  1.9192497836353113
#  1.9192497836353115
#  1.9192497836353113
#  1.9192497836353115
#  1.9192497836353113
#  1.9192497836353115
#  1.9192497836353113
#  1.9192497836353115
#
# Test correct:
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17]

# %% [markdown]
# ## (6) ReLU + Softmax + LogLikelihood (Result 6)

# %%
net6 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net6.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.ReLU, act_output=network2.Softmax)

net6.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.0978694103628626
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.10265106017516
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.0978909807841661
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031230217405117
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.097891593631602
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.103131682432255
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.097891605956821
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318413233266
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.0978916062045687
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318442875535
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.0978916062095643
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.103131844343714
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.0978916062096644
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443447928
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.0978916062096675
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.103131844344814
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Training error:
#  1.0978694103628626
#  1.0978909807841661
#  1.097891593631602
#  1.097891605956821
#  1.0978916062045687
#  1.0978916062095643
#  1.0978916062096644
#  1.0978916062096675
#  1.0978916062096673
#  1.0978916062096673
#  1.0978916062096673
#  1.0978916062096673
#  1.0978916062096673
#  1.0978916062096673
#  1.0978916062096673
#
# Training correct:
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33]
#
# Test error:
#  1.10265106017516
#  1.1031230217405117
#  1.103131682432255
#  1.1031318413233266
#  1.1031318442875535
#  1.103131844343714
#  1.1031318443447928
#  1.103131844344814
#  1.1031318443448146
#  1.1031318443448146
#  1.1031318443448146
#  1.1031318443448146
#  1.1031318443448146
#  1.1031318443448146
#  1.1031318443448146
#
# Test correct:
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17]

# %% [markdown]
# ## (7) Tanh + Sigmoid + Quadratic (Result 7)

# %%
net6 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net6.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Tanh, act_output=network2.Sigmoid)

net6.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.33443116540231776
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.3363579316611686
# Accuracy on evaluation data: 18 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.33175799332119593
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33326213908032815
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.2888319510914468
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.2898615890727258
# Accuracy on evaluation data: 38 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.2187945048778968
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.21994496188727214
# Accuracy on evaluation data: 38 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.19532043187167233
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1975753300018062
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.1855297148025347
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.18851326412153177
# Accuracy on evaluation data: 35 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.18041560683139668
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.18380157993229201
# Accuracy on evaluation data: 35 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.17730855793255565
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.18092380021642968
# Accuracy on evaluation data: 35 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.17523125989906965
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17898859908100612
# Accuracy on evaluation data: 35 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.17375076811304133
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1776028110886066
# Accuracy on evaluation data: 35 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.17264571173278204
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17656425232755787
# Accuracy on evaluation data: 35 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.17179130790365219
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1757584405091967
# Accuracy on evaluation data: 35 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.17111209145146633
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1751159110291929
# Accuracy on evaluation data: 35 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.17055987550890314
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17459216589672666
# Accuracy on evaluation data: 35 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.1701025186391921
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1741574243227054
# Accuracy on evaluation data: 35 / 55
#
# Training error:
#  0.33443116540231776
#  0.33175799332119593
#  0.2888319510914468
#  0.2187945048778968
#  0.19532043187167233
#  0.1855297148025347
#  0.18041560683139668
#  0.17730855793255565
#  0.17523125989906965
#  0.17375076811304133
#  0.17264571173278204
#  0.17179130790365219
#  0.17111209145146633
#  0.17055987550890314
#  0.1701025186391921
#
# Training correct:
#  [32, 33, 62, 62, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65]
#
# Test error:
#  0.3363579316611686
#  0.33326213908032815
#  0.2898615890727258
#  0.21994496188727214
#  0.1975753300018062
#  0.18851326412153177
#  0.18380157993229201
#  0.18092380021642968
#  0.17898859908100612
#  0.1776028110886066
#  0.17656425232755787
#  0.1757584405091967
#  0.1751159110291929
#  0.17459216589672666
#  0.1741574243227054
#
# Test correct:
#  [18, 17, 38, 38, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35]

# %% [markdown]
# ## (8) Tanh + Tanh + Quadratic (Result 8)

# %%
net7 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net7.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Tanh, act_output=network2.Tanh)

net7.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.5632335301767954
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.6447817575121706
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.7700632291151652
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.8449848877027488
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.5001812828570167
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5351845062575689
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.557077858708229
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5640765578601548
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.4008025521113836
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.4146963617638642
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.7515323812848451
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.8225619187820685
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.6150277987650365
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 1.5628155810697602
# Accuracy on evaluation data: 20 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.6128596692916346
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.645033501160494
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.5134550390915051
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5728424450782617
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.7513250588585554
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.8214008000533182
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 1.4490754804039019
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.4702885893410298
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 1.5583541040266387
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5650637483663263
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 1.4579787099250732
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5021196400954142
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 1.574436392445844
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5905689160980765
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 1.4493303696063904
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.4643282053222855
# Accuracy on evaluation data: 17 / 55
#
# Training error:
#  1.5632335301767954
#  1.7700632291151652
#  1.5001812828570167
#  1.557077858708229
#  1.4008025521113836
#  1.7515323812848451
#  1.6150277987650365
#  1.6128596692916346
#  1.5134550390915051
#  1.7513250588585554
#  1.4490754804039019
#  1.5583541040266387
#  1.4579787099250732
#  1.574436392445844
#  1.4493303696063904
#
# Training correct:
#  [33, 33, 33, 33, 33, 33, 30, 33, 33, 33, 33, 33, 33, 33, 33]
#
# Test error:
#  1.6447817575121706
#  1.8449848877027488
#  1.5351845062575689
#  1.5640765578601548
#  1.4146963617638642
#  1.8225619187820685
#  1.5628155810697602
#  1.645033501160494
#  1.5728424450782617
#  1.8214008000533182
#  1.4702885893410298
#  1.5650637483663263
#  1.5021196400954142
#  1.5905689160980765
#  1.4643282053222855
#
# Test correct:
#  [17, 17, 17, 17, 17, 17, 20, 17, 17, 17, 17, 17, 17, 17, 17]

# %% [markdown]
# ## (9) Sigmoid + Sigmoid + Quadratic + L2 (Result 9)

# %%
net8 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net8.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid, regularization="L2")

net8.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, lmbda=3.0, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.45886398333113254
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.5509298016398526
# Accuracy on evaluation data: 18 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.396623357612462
# Accuracy on training data: 31 / 95
# Cost on evaluation data: 0.4441627862193589
# Accuracy on evaluation data: 20 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.35964315066025077
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.38666765720485874
# Accuracy on evaluation data: 38 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.3426284579117333
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.36158436118873444
# Accuracy on evaluation data: 38 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.33416123022543753
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.35010483170635776
# Accuracy on evaluation data: 38 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.3294987724480264
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.34509465468848194
# Accuracy on evaluation data: 38 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.32661002837142633
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.3430922517975508
# Accuracy on evaluation data: 38 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.3246207815335592
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.34246860387826106
# Accuracy on evaluation data: 38 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.32317949516790373
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.3425544533429334
# Accuracy on evaluation data: 38 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.3221101647238849
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.3430183499957253
# Accuracy on evaluation data: 38 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.32130764170816845
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.3436662370213027
# Accuracy on evaluation data: 39 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.3207007860256327
# Accuracy on training data: 63 / 95
# Cost on evaluation data: 0.3443769166605408
# Accuracy on evaluation data: 39 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.32023794744722905
# Accuracy on training data: 66 / 95
# Cost on evaluation data: 0.3450754538270465
# Accuracy on evaluation data: 42 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.3198807020878354
# Accuracy on training data: 71 / 95
# Cost on evaluation data: 0.3457187003821496
# Accuracy on evaluation data: 44 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.3196005230464391
# Accuracy on training data: 74 / 95
# Cost on evaluation data: 0.3462854182042949
# Accuracy on evaluation data: 47 / 55
#
# Training error:
#  0.45886398333113254
#  0.396623357612462
#  0.35964315066025077
#  0.3426284579117333
#  0.33416123022543753
#  0.3294987724480264
#  0.32661002837142633
#  0.3246207815335592
#  0.32317949516790373
#  0.3221101647238849
#  0.32130764170816845
#  0.3207007860256327
#  0.32023794744722905
#  0.3198807020878354
#  0.3196005230464391
#
# Training correct:
#  [30, 31, 62, 62, 62, 62, 62, 62, 62, 62, 62, 63, 66, 71, 74]
#
# Test error:
#  0.5509298016398526
#  0.4441627862193589
#  0.38666765720485874
#  0.36158436118873444
#  0.35010483170635776
#  0.34509465468848194
#  0.3430922517975508
#  0.34246860387826106
#  0.3425544533429334
#  0.3430183499957253
#  0.3436662370213027
#  0.3443769166605408
#  0.3450754538270465
#  0.3457187003821496
#  0.3462854182042949
#
# Test correct:
#  [18, 20, 38, 38, 38, 38, 38, 38, 38, 38, 39, 39, 42, 44, 47]

# %% [markdown]
# ## (10) Sigmoid + Sigmoid + Quadratic + L1 (Result 10)

# %%
net9 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net9.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid, regularization ="L1")

net9.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, lmbda=3.0,
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.48278311429996934
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.5870450154136593
# Accuracy on evaluation data: 20 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.5102409852779146
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.6372644856659047
# Accuracy on evaluation data: 20 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.5425133441423221
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.6944134808002052
# Accuracy on evaluation data: 20 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.5775785466229337
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.7557206375451733
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.6143713670047994
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.8196800167777613
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.6523051915104626
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.8854348626488002
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.6910305773749627
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.9524599913575578
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.7303264937998757
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.0204152039221086
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.7700463767969421
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.0890703878387313
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.810089299908642
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1582643934690324
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.8503835900881083
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.227881121147235
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.8908770262691095
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.2978349333840116
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.93153072078128
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.3680613894309162
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.9723151623230427
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.4385111572308102
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 1.0132075799102958
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5091458970407543
# Accuracy on evaluation data: 17 / 55
#
# Training error:
#  0.48278311429996934
#  0.5102409852779146
#  0.5425133441423221
#  0.5775785466229337
#  0.6143713670047994
#  0.6523051915104626
#  0.6910305773749627
#  0.7303264937998757
#  0.7700463767969421
#  0.810089299908642
#  0.8503835900881083
#  0.8908770262691095
#  0.93153072078128
#  0.9723151623230427
#  1.0132075799102958
#
# Training correct:
#  [30, 30, 30, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33]
#
# Test error:
#  0.5870450154136593
#  0.6372644856659047
#  0.6944134808002052
#  0.7557206375451733
#  0.8196800167777613
#  0.8854348626488002
#  0.9524599913575578
#  1.0204152039221086
#  1.0890703878387313
#  1.1582643934690324
#  1.227881121147235
#  1.2978349333840116
#  1.3680613894309162
#  1.4385111572308102
#  1.5091458970407543
#
# Test correct:
#  [20, 20, 20, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17]

# %% [markdown]
# ## (11) Sigmoid + Sigmoid + Quadratic + dropout = 0.1 (Result 11)

# %%
net10 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net10.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid, dropoutpercent=0.1)

net10.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.3364503699145236
# Accuracy on training data: 31 / 95
# Cost on evaluation data: 0.3402025822867445
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.3327855918407874
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3340686878204866
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.33155797400379755
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3319410074862998
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.3271201621877951
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.32718752929328093
# Accuracy on evaluation data: 20 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3065651235938511
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.3076180757610856
# Accuracy on evaluation data: 18 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.2771763313890076
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.27679225257910406
# Accuracy on evaluation data: 38 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.25685928541207304
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.2563835450919302
# Accuracy on evaluation data: 38 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.2419349794680334
# Accuracy on training data: 63 / 95
# Cost on evaluation data: 0.24238661855849222
# Accuracy on evaluation data: 40 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.23040260914853766
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.230522233615575
# Accuracy on evaluation data: 38 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.22184059363907732
# Accuracy on training data: 66 / 95
# Cost on evaluation data: 0.22305869911447898
# Accuracy on evaluation data: 41 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.21534379223510108
# Accuracy on training data: 70 / 95
# Cost on evaluation data: 0.21687431079097189
# Accuracy on evaluation data: 44 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.21016865594058093
# Accuracy on training data: 63 / 95
# Cost on evaluation data: 0.2108418787971846
# Accuracy on evaluation data: 38 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.20582114803621293
# Accuracy on training data: 63 / 95
# Cost on evaluation data: 0.20693579055053016
# Accuracy on evaluation data: 39 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.2024287156832887
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.20399057949627722
# Accuracy on evaluation data: 41 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.19923421899242208
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.2007632455044519
# Accuracy on evaluation data: 40 / 55
#
# Training error:
#  0.3364503699145236
#  0.3327855918407874
#  0.33155797400379755
#  0.3271201621877951
#  0.3065651235938511
#  0.2771763313890076
#  0.25685928541207304
#  0.2419349794680334
#  0.23040260914853766
#  0.22184059363907732
#  0.21534379223510108
#  0.21016865594058093
#  0.20582114803621293
#  0.2024287156832887
#  0.19923421899242208
#
# Training correct:
#  [31, 33, 33, 30, 32, 62, 62, 63, 62, 66, 70, 63, 63, 65, 64]
#
# Test error:
#  0.3402025822867445
#  0.3340686878204866
#  0.3319410074862998
#  0.32718752929328093
#  0.3076180757610856
#  0.27679225257910406
#  0.2563835450919302
#  0.24238661855849222
#  0.230522233615575
#  0.22305869911447898
#  0.21687431079097189
#  0.2108418787971846
#  0.20693579055053016
#  0.20399057949627722
#  0.2007632455044519
#
# Test correct:
#  [17, 17, 17, 20, 18, 38, 38, 40, 38, 41, 44, 38, 39, 41, 40]

# %% [markdown]
# ## (12) Sigmoid + Sigmoid + Quadratic + dropout = 0.5 (Result 12)

# %%
net11 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net11.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid, regularization=None, dropoutpercent=0.5 )

net11.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.338158009155523
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3433953146564178
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.33259431889033375
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3333703560130514
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.3322848564940629
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.3304668997930275
# Accuracy on evaluation data: 20 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.3239104833178476
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.3225962192447051
# Accuracy on evaluation data: 20 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.30395573831351547
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.3009620388783313
# Accuracy on evaluation data: 38 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.28749907772991756
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.2878849823168276
# Accuracy on evaluation data: 18 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.27591758094080043
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.27641369349151795
# Accuracy on evaluation data: 38 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.27167276914582683
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.27190007378766884
# Accuracy on evaluation data: 38 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.2584907188255249
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.25819077823868475
# Accuracy on evaluation data: 38 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.2534465143795473
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.2539013881582921
# Accuracy on evaluation data: 40 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.2475812574555015
# Accuracy on training data: 67 / 95
# Cost on evaluation data: 0.24835084497349388
# Accuracy on evaluation data: 41 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.24232577727497115
# Accuracy on training data: 72 / 95
# Cost on evaluation data: 0.2432807508620979
# Accuracy on evaluation data: 47 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.23796327607650658
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.24020695126336003
# Accuracy on evaluation data: 35 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.2382408393621762
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.24159062343246607
# Accuracy on evaluation data: 35 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.23483646503284486
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.2373101983945113
# Accuracy on evaluation data: 35 / 55
#
# Training error:
#  0.338158009155523
#  0.33259431889033375
#  0.3322848564940629
#  0.3239104833178476
#  0.30395573831351547
#  0.28749907772991756
#  0.27591758094080043
#  0.27167276914582683
#  0.2584907188255249
#  0.2534465143795473
#  0.2475812574555015
#  0.24232577727497115
#  0.23796327607650658
#  0.2382408393621762
#  0.23483646503284486
#
# Training correct:
#  [33, 33, 30, 30, 62, 32, 62, 62, 62, 65, 67, 72, 65, 65, 65]
#
# Test error:
#  0.3433953146564178
#  0.3333703560130514
#  0.3304668997930275
#  0.3225962192447051
#  0.3009620388783313
#  0.2878849823168276
#  0.27641369349151795
#  0.27190007378766884
#  0.25819077823868475
#  0.2539013881582921
#  0.24835084497349388
#  0.2432807508620979
#  0.24020695126336003
#  0.24159062343246607
#  0.2373101983945113
#
# Test correct:
#  [17, 17, 20, 20, 38, 18, 38, 38, 38, 40, 41, 47, 35, 35, 35]
